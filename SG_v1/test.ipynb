# %%
for i in range(5):
    print(f"Node {i}:")
# Out:
# Node 0:
# Node 1:
# Node 2:
# Node 3:
# Node 4:

# %%
x = [1,2,3,4,5]

y = []

# %%
for i in range(len(x)):
    y.append(x[i]**2)
print(y)
# Out:
# [1, 4, 9, 16, 25]
