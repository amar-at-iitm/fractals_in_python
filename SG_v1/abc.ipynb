# %% [markdown]
# # Factal Env

# %%
import numpy as np
import pandas as pd

# %%
a = np.array([1, 2, 3])
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[1, 2], [3, 4]])
print(b)
# Out:
# [[1 2]
#  [3 4]]

# %%
c = np.vectorize(lambda x: x**2)
print(c(a))
# Out:
# [1 4 9]

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
